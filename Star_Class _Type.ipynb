# %% [markdown]
# # Star_Type_Prediction ML project

# %% [markdown]
# ## importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Import dataset using pandas dataframe

# %%
df = pd.read_csv("/content/6 class csv.csv")
df
# Out:
#      Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
# 0               3068          0.002400        0.1700                   16.12
# 1               3042          0.000500        0.1542                   16.60
# 2               2600          0.000300        0.1020                   18.70
# 3               2800          0.000200        0.1600                   16.65
# 4               1939          0.000138        0.1030                   20.06
# ..               ...               ...           ...                     ...
# 235            38940     374830.000000     1356.0000                   -9.93
# 236            30839     834042.000000     1194.0000                  -10.63
# 237             8829     537493.000000     1423.0000                  -10.73
# 238             9235     404940.000000     1112.0000                  -11.23
# 239            37882     294903.000000     1783.0000                   -7.80
#
#      Star type Star color Spectral Class
# ...

# %%
# find empty cell in data set
df.isnull().sum()
# Out:
# Temperature (K)           0
# Luminosity(L/Lo)          0
# Radius(R/Ro)              0
# Absolute magnitude(Mv)    0
# Star type                 0
# Star color                0
# Spectral Class            0
# dtype: int64

# %%
# find duplicalted in dataset
df.duplicated().sum()
# Out:
# 0

# %%
# find information about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Temperature (K)         240 non-null    int64
#  1   Luminosity(L/Lo)        240 non-null    float64
#  2   Radius(R/Ro)            240 non-null    float64
#  3   Absolute magnitude(Mv)  240 non-null    float64
#  4   Star type               240 non-null    int64
#  5   Star color              240 non-null    object
#  6   Spectral Class          240 non-null    object
# dtypes: float64(3), int64(2), object(2)
# memory usage: 13.2+ KB

# %%
# describe features of dataset
df.describe()
# Out:
#        Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  \
# count       240.000000        240.000000    240.000000
# mean      10497.462500     107188.361635    237.157781
# std        9552.425037     179432.244940    517.155763
# min        1939.000000          0.000080      0.008400
# 25%        3344.250000          0.000865      0.102750
# 50%        5776.000000          0.070500      0.762500
# 75%       15055.500000     198050.000000     42.750000
# max       40000.000000     849420.000000   1948.500000
#
#        Absolute magnitude(Mv)   Star type
# count              240.000000  240.000000
# mean                 4.382396    2.500000
# std                 10.532512    1.711394
# min                -11.920000    0.000000
# 25%                 -6.232500    1.000000
# 50%                  8.313000    2.500000
# 75%                 13.697500    4.000000
# max                 20.060000    5.000000

# %% [markdown]
# # Data visualization dependent on "Specteral Class"

# %%
fig, ax = plt.subplots(1,3, figsize=(9,3) , sharey = True )
#ax.bar(df['Absolute magnitude(Mv)'], df['Spectral Class'] , color='red' ,  label = " ")
ax[0].bar( df['Spectral Class'],df['Absolute magnitude(Mv)'])
ax[1].scatter( df['Spectral Class'],df['Absolute magnitude(Mv)'])
ax[2].plot( df['Spectral Class'],df['Absolute magnitude(Mv)'])
fig.suptitle(" magnitude V/S Spectral Class")
# Out:
# Text(0.5, 0.98, ' magnitude V/S Spectral Class')

# %%
plt.figure(figsize = (10,6))

plt.bar(df['Temperature (K)'], df['Spectral Class'] , color='red' ,  label = " magnitude V/S Spectral Class ")
plt.xlabel("Temperature (K)")
plt.ylabel("Spectral Class")
plt.title("Temperature (K) V/S Spectral Class ")
plt.show()

# %%
fig, ax = plt.subplots(1,3, figsize=(9, 3), sharey=True)
#ax.plot(df['Temperature (K)'], df['Spectral Class'] , color='red' ,  label = " magnitude V/S Spectral Class ")
ax[0].bar(df['Temperature (K)'], df['Spectral Class'])
ax[1].plot(df['Temperature (K)'], df['Spectral Class'] ,color = 'red')
ax[2].scatter(df['Temperature (K)'], df['Spectral Class'])
fig.suptitle("Temperature (K) V/S Spectral Class ")
# Out:
# Text(0.5, 0.98, 'Temperature (K) V/S Spectral Class ')

# %%
fig, ax = plt.subplots(1,3, figsize=(9,3) , sharey = True )
#ax.bar(df['Radius(R/Ro)'], df['Spectral Class'] , color='red' ,  label = " ")  Luminosity(L/Lo)	Radius(R/Ro)
ax[0].bar( df['Spectral Class'],df['Radius(R/Ro)'])
ax[1].scatter( df['Spectral Class'],df['Radius(R/Ro)'])
ax[2].plot( df['Spectral Class'],df['Radius(R/Ro)'])
fig.suptitle(" Radius(R/Ro) V/S Spectral Class")
# Out:
# Text(0.5, 0.98, ' Radius(R/Ro) V/S Spectral Class')

# %%
fig, ax = plt.subplots(1,3, figsize=(9,3) , sharey = True )
#ax.bar(df['Luminosity(L/Lo)'], df['Spectral Class'] , color='red' ,  label = " ")  Luminosity(L/Lo)	Luminosity(L/Lo)
ax[0].bar( df['Spectral Class'],df['Luminosity(L/Lo)'])
ax[1].scatter( df['Spectral Class'],df['Luminosity(L/Lo)'])
ax[2].plot( df['Spectral Class'],df['Luminosity(L/Lo)'])
fig.suptitle(" Luminosity(L/Lo) V/S Spectral Class")
# Out:
# Text(0.5, 0.98, ' Luminosity(L/Lo) V/S Spectral Class')

# %%
pfig, ax = plt.subplots(1,3, figsize=(9,3) , sharey = True )
#ax.bar(df['Star type'], df['Spectral Class'] , color='red' ,  label = " ")  Star type	Star type
ax[0].bar( df['Spectral Class'],df['Star type'])
ax[1].scatter( df['Spectral Class'],df['Star type'])
ax[2].plot( df['Spectral Class'],df['Star type'])
fig.suptitle(" Star type V/S Spectral Class")
# Out:
# Text(0.5, 0.98, ' Star type V/S Spectral Class')

# %%
pfig, ax = plt.subplots(1,3, figsize=(14,3) , sharey = True )

#ax.bar( df['Spectral Class'] , color='red' ,  label = " ")  Star color	Star color
ax[0].bar( df['Spectral Class'],df['Star color'])
ax[1].scatter( df['Spectral Class'],df['Star color'])
ax[2].plot( df['Spectral Class'],df['Star color'])
fig.suptitle(" Star color V/S Spectral Class")
# Out:
# Text(0.5, 0.98, ' Star color V/S Spectral Class')

# %%
sns.boxplot(df['Spectral Class'])
# Out:
# <Axes: ylabel='Spectral Class'>

# %% [markdown]
# ## Data - Preprocessing

# %%
# categorical variable convert into numeric form using pandas get_dummies()
df['Star color'].unique()
# Out:
# array(['Red', 'Blue White', 'White', 'Yellowish White', 'Blue white',
#        'Pale yellow orange', 'Blue', 'Blue-white', 'Whitish',
#        'yellow-white', 'Orange', 'White-Yellow', 'white', 'Blue ',
#        'yellowish', 'Yellowish', 'Orange-Red', 'Blue white ',
#        'Blue-White'], dtype=object)

# %%
color = pd.get_dummies(df['Star color'])
new_df = pd.get_dummies(df, columns = ['Star color'])
new_df
# Out:
#      Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
# 0               3068          0.002400        0.1700                   16.12
# 1               3042          0.000500        0.1542                   16.60
# 2               2600          0.000300        0.1020                   18.70
# 3               2800          0.000200        0.1600                   16.65
# 4               1939          0.000138        0.1030                   20.06
# ..               ...               ...           ...                     ...
# 235            38940     374830.000000     1356.0000                   -9.93
# 236            30839     834042.000000     1194.0000                  -10.63
# 237             8829     537493.000000     1423.0000                  -10.73
# 238             9235     404940.000000     1112.0000                  -11.23
# 239            37882     294903.000000     1783.0000                   -7.80
#
# ...

# %% [markdown]
# ## Devide into target and independent variables

# %%
red_val= color.columns[0]
red_val
# Out:
# 'Blue'

# %%
X = new_df.drop(columns=['Spectral Class'])
y= new_df['Spectral Class']
X,y

# %% [markdown]
# ## train-test-split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y ,test_size = 0.3 , random_state = 42)
X_train

# %% [markdown]
# ## Standardization of Data X_train,X_test

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# fit and transform train_x data
X_train_scaled = scaler.fit_transform(X_train)

# just taransform the test_x data ( secure from data-leakage)
X_test_scaled = scaler.transform(X_test)

X_train_scaled

# %% [markdown]
# ## Apply different algorithms for test which algo apply well predict on dependent variable

# %% [markdown]
# ### DecisionTree Algorithm

# %%
# import DecisionTree Classifier

from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()


# fit the model
model1 = dt.fit(X_train_scaled , y_train)

# predict the model
pred = dt.predict(X_test_scaled)
pred

# %% [markdown]
# ### Accuracy score

# %%
from sklearn.metrics import accuracy_score
accuracy =accuracy_score(y_test , pred)
print(f'Accuracy_Score : {accuracy}')

# %% [markdown]
# ### RandomForest Classifier

# %%
# import RandomForest Classifier

from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()


# fit the model
model2 = rfc.fit(X_train_scaled , y_train)

# predict the model
pred = model2.predict(X_test_scaled)
pred

# %% [markdown]
# ### Accuracy score

# %%
from sklearn.metrics import accuracy_score
accuracy =accuracy_score(y_test , pred)
print(f'Accuracy_Score : {accuracy}')

# %% [markdown]
# # Logistic Regression

# %%
# import Logistic Regression

from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()


# fit the model
model3 = lr.fit(X_train_scaled , y_train)

# predict the model
pred = model3.predict(X_test_scaled)
pred

# %% [markdown]
# ### Accuracy Score

# %%
from sklearn.metrics import accuracy_score
accuracy =accuracy_score(y_test , pred)
print(f'Accuracy_Score : {accuracy}')

# %% [markdown]
# ### K-Nearest Neighbor Algorithm

# %%
# import K-Nearest-Neighbors

from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()


# fit the model
model4 = knn.fit(X_train_scaled , y_train)

# predict the model
pred = model4.predict(X_test_scaled)
pred

# %% [markdown]
# ### Accuracy_score

# %%
from sklearn.metrics import accuracy_score
accuracy =accuracy_score(y_test , pred)
print(f'Accuracy_Score : {accuracy}')

# %% [markdown]
# ### import pickle file

# %%
#import pickle
pickle.dump(model3,open('Star_Class_type.pkl', 'wb'))

# %% [markdown]
# #  Best Classifier Algorithms for this classifier dataset is RandomForest and LogisticRegression Algo rithms both of apply this get highest accuracy dependent on this dataset
